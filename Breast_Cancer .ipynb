# %% [markdown]
# #**data preprocessing**

# %% [markdown]
# **Importing the Pandas library for data manipulation and analysis**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Reading the breast cancer dataset from a CSV file**

# %%
df = pd.read_csv("E:\\breast-cancer.csv")

# %% [markdown]
# **Displaying the first few rows of the DataFrame to get an overview of the data**

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# **Counting the total number of duplicate rows in the DataFrame**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Displaying a summary of the DataFrame including the number of entries, columns, data types, and non-null counts**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df["id"] = df["id"].astype(object)

# %% [markdown]
# **Counting the number of null values in each column of the DataFrame**

# %%
df.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %% [markdown]
# **Descriptive statistics for the numerical columns in the DataFrame**

# %%
df.describe().T
# Out:
#                          count        mean         std         min  \
# radius_mean              569.0   14.127292    3.524049    6.981000
# texture_mean             569.0   19.289649    4.301036    9.710000
# perimeter_mean           569.0   91.969033   24.298981   43.790000
# area_mean                569.0  654.889104  351.914129  143.500000
# smoothness_mean          569.0    0.096360    0.014064    0.052630
# compactness_mean         569.0    0.104341    0.052813    0.019380
# concavity_mean           569.0    0.088799    0.079720    0.000000
# concave points_mean      569.0    0.048919    0.038803    0.000000
# symmetry_mean            569.0    0.181162    0.027414    0.106000
# fractal_dimension_mean   569.0    0.062798    0.007060    0.049960
# radius_se                569.0    0.405172    0.277313    0.111500
# texture_se               569.0    1.216853    0.551648    0.360200
# perimeter_se             569.0    2.866059    2.021855    0.757000
# ...

# %% [markdown]
# **Unique values of "diagnosis"**

# %%
df["diagnosis"].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %% [markdown]
# **Count of each diagnosis: 'M' for malignant and 'B' for benign**

# %%
df["diagnosis"].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %% [markdown]
# **Save cleaned Data**

# %%
df.to_csv('Cleaned_Breast Cancer.csv', index=False)

# %% [markdown]
# #**EDA**

# %%
diagnosis_counts = df['diagnosis'].value_counts()

print(diagnosis_counts)

diagnosis_counts.plot(kind='bar', color=['lightcoral', 'lightblue'])
plt.title('Distribution of Diagnosis (M vs B)')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %% [markdown]
# **boxplots visualize the relationship between the features 'radius_mean' and 'perimeter_mean' with the diagnosis type **

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x='diagnosis', y='radius_mean', data=df)
plt.title('Boxplot of Radius Mean by Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Radius Mean')

plt.subplot(1, 2, 2)
sns.boxplot(x='diagnosis', y='perimeter_mean', data=df)
plt.title('Boxplot of Perimeter Mean by Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Perimeter Mean')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
plt.figure(figsize=(12, 6))


plt.subplot(1, 2, 1)
sns.boxplot(x='diagnosis', y='smoothness_mean', data=df)
plt.title('Smoothness Mean by Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Smoothness Mean')


plt.subplot(1, 2, 2)
sns.boxplot(x='diagnosis', y='concavity_mean', data=df)
plt.title('Concavity Mean by Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Concavity Mean')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
# Encode the diagnosis (M -> 1, B -> 0) for easier plotting
df['diagnosis'] = df['diagnosis'].apply(lambda x: 'Malignant' if x == 'M' else 'Benign')

# Create a new DataFrame with only relevant columns
radius_data = df[['diagnosis', 'radius_mean', 'radius_worst']]

# Melt the DataFrame to have 'radius_mean' and 'radius_worst' in a single column for plotting
radius_melted = radius_data.melt(id_vars='diagnosis', var_name='Radius Type', value_name='Value')

# Plot the boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Radius Type', y='Value', hue='diagnosis', data=radius_melted, palette='deep')
plt.title('Comparison of Radius Mean and Radius Worst by Diagnosis')
plt.ylabel('Radius Value')
plt.show()

# %%
# Encode the diagnosis (M -> 1, B -> 0) for easier plotting
df['diagnosis'] = df['diagnosis'].apply(lambda x: 'Malignant' if x == 'M' else 'Benign')

# Create a new DataFrame with only relevant columns
radius_data = df[['diagnosis', 'texture_mean', 'texture_worst']]

# Melt the DataFrame to have 'radius_mean' and 'radius_worst' in a single column for plotting
radius_melted = radius_data.melt(id_vars='diagnosis', var_name='Radius Type', value_name='Value')

# Plot the boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Radius Type', y='Value', hue='diagnosis', data=radius_melted, palette='deep')
plt.title('Comparison of Texture Mean and Texture Worst by Diagnosis')
plt.ylabel('Texture Value')
plt.show()
